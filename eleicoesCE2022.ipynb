# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('candidatos_ce.csv', header=None, encoding = "ISO-8859-1", delimiter=';')
display(df)
# Out:
#               0           1            2                3                  4   \
# 0     DT_GERACAO  HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO
# 1     19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 2     19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 3     19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 4     19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# ...          ...         ...          ...              ...                ...
# 1014  19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 1015  19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 1016  19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 1017  19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
# 1018  19/09/2022    13:07:42         2022                2  ELEIÇÃO ORDINÁRIA
#
# ...

# %%
df.columns = df.iloc[0]
df = df.drop(0)
df.head(10)
# Out:
# 0   DT_GERACAO HH_GERACAO ANO_ELEICAO CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 1   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 2   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 3   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 4   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 5   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 6   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 7   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 8   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 9   19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
# 10  19/09/2022   13:07:42        2022               2  ELEIÇÃO ORDINÁRIA
#
# 0  NR_TURNO CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 1         1        546  Eleições Gerais Estaduais 2022  02/10/2022
# ...

# %%
df = df.drop(columns=['DT_GERACAO','HH_GERACAO','ANO_ELEICAO','CD_TIPO_ELEICAO','NM_TIPO_ELEICAO','NR_TURNO','CD_ELEICAO','DS_ELEICAO','DT_ELEICAO','TP_ABRANGENCIA','SG_UF','SG_UE','NM_UE','SQ_CANDIDATO','NM_CANDIDATO','NM_SOCIAL_CANDIDATO','NR_PROCESSO','NM_TIPO_DESTINACAO_VOTOS','NR_CPF_CANDIDATO','NM_EMAIL','CD_SITUACAO_CANDIDATURA','ST_DECLARAR_BENS','NR_PROTOCOLO_CANDIDATURA','CD_SITUACAO_CANDIDATO_PLEITO','CD_SITUACAO_CANDIDATO_URNA','ST_CANDIDATO_INSERIDO_URNA','CD_SITUACAO_CANDIDATO_TOT','DS_SITUACAO_CANDIDATO_TOT','ST_PREST_CONTAS','TP_AGREMIACAO','VR_DESPESA_MAX_CAMPANHA','CD_SIT_TOT_TURNO','DS_SIT_TOT_TURNO','DS_SITUACAO_CANDIDATO_PLEITO','DS_SITUACAO_CANDIDATO_URNA','NM_PARTIDO','CD_COR_RACA','NR_FEDERACAO','CD_DETALHE_SITUACAO_CAND','DS_DETALHE_SITUACAO_CAND','NM_FEDERACAO','SG_FEDERACAO','DS_COMPOSICAO_FEDERACAO','SQ_COLIGACAO','NM_COLIGACAO','DS_COMPOSICAO_COLIGACAO','CD_NACIONALIDADE','DS_NACIONALIDADE','ST_REELEICAO','NR_TITULO_ELEITORAL_CANDIDATO'])
df.head()
# Out:
# 0 CD_CARGO           DS_CARGO NR_CANDIDATO NM_URNA_CANDIDATO  \
# 1        6   DEPUTADO FEDERAL         4522      JANE DO VALE
# 2        7  DEPUTADO ESTADUAL        23323  ADAILTON BRANDÃO
# 3        7  DEPUTADO ESTADUAL        36010  ESCOTEIRO OZIVAN
# 4        7  DEPUTADO ESTADUAL        55000      ERIKA AMORIM
# 5        6   DEPUTADO FEDERAL         1145              TEFA
#
# 0 DS_SITUACAO_CANDIDATURA NR_PARTIDO SG_PARTIDO SG_UF_NASCIMENTO  \
# 1                    APTO         45       PSDB               CE
# 2                  INAPTO         23  CIDADANIA               CE
# 3                    APTO         36       AGIR               CE
# 4                  INAPTO         55        PSD               CE
# 5                    APTO         11         PP               CE
#
# 0 CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  ... NR_IDADE_DATA_POSSE  \
# 1                      -3               FORTALEZA  ...                  58
# ...

# %%
df.rename(columns={
    'CD_CARGO':'ID Cargo',
    'DS_CARGO':'Cargo',
    'NR_CANDIDATO':'Número Candidato',
    'NM_URNA_CANDIDATO':'Nome Candidato',
    'DS_SITUACAO_CANDIDATURA':'Situação',
    'NR_PARTIDO':'Número Partido',
    'SG_PARTIDO':'Sigla Partido',
    'SG_UF_NASCIMENTO':'UF Nascimento',
    'CD_MUNICIPIO_NASCIMENTO':'ID Mun Nasc',
    'NM_MUNICIPIO_NASCIMENTO':'Municipio',
    'NR_IDADE_DATA_POSSE':'Idade Candidato',
    'CD_GENERO':'ID Genero',
    'DS_GENERO':'Genero',
    'CD_GRAU_INSTRUCAO':'ID Grau Instrução',
    'DS_GRAU_INSTRUCAO':'Grau Instrução',
    'CD_ESTADO_CIVIL':'ID Estado Cívil',
    'DS_ESTADO_CIVIL':'Estado Civil',
    'DS_COR_RACA':'Raça',
    'CD_OCUPACAO':'ID Ocupação',
    'DS_OCUPACAO':'Ocupação'
}, inplace=True)

df.head()
# Out:
# 0 ID Cargo              Cargo Número Candidato    Nome Candidato Situação  \
# 1        6   DEPUTADO FEDERAL             4522      JANE DO VALE     APTO
# 2        7  DEPUTADO ESTADUAL            23323  ADAILTON BRANDÃO   INAPTO
# 3        7  DEPUTADO ESTADUAL            36010  ESCOTEIRO OZIVAN     APTO
# 4        7  DEPUTADO ESTADUAL            55000      ERIKA AMORIM   INAPTO
# 5        6   DEPUTADO FEDERAL             1145              TEFA     APTO
#
# 0 Número Partido Sigla Partido UF Nascimento ID Mun Nasc  Municipio  ...  \
# 1             45          PSDB            CE          -3  FORTALEZA  ...
# 2             23     CIDADANIA            CE          -3  FORTALEZA  ...
# 3             36          AGIR            CE          -3  FORTALEZA  ...
# 4             55           PSD            CE          -3  FORTALEZA  ...
# 5             11            PP            CE          -3    QUIXADÁ  ...
#
# 0 Idade Candidato ID Genero     Genero ID Grau Instrução  \
# ...
